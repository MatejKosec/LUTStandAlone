# %% [markdown]
# # LUT Verificaton

# %%
import os 
import sys
import matplotlib.pyplot as plt
import ConvergenceLibrary 
from ConvergenceLibrary import RandomSamples, PRGrid, SU2_InterpolatedData, SciPy_InterpolatedData
from ConvergenceLibrary import RefinementLevel, PRGridSkewed, RestartSamples
reload(ConvergenceLibrary)
from shutil import copyfile
# %matplotlib inline
#%matplotlib notebook

# %% [markdown]
# ## Plot the thermo pair grids for a skweded P-rho combination

# %%
#grids = PRGridSkewed("SkewedMeshes/CO2_skewed.dat")
#grids = PRGridSkewed("SkewedMeshes/CO2_skewed_double.dat")
#grids = PRGridSkewed("SkewedMeshes/MDM_skewed.dat")
#restart=RestartSamples("SkewedMeshes/RestartCompare/MDM_restart_flow.dat",'2D')
restart=RestartSamples("SkewedMeshes/RestartCompare/Orchid_restart_flow.dat", '3D')
#restart=RestartSamples("SkewedMeshes/RestartCompare/Orchid_nozzle_restart_flow.dat")
# Out:
# Restart points:  8348

# %%
restart.restarts[:,9] - restart.Pressure
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %% [markdown]
# ## PRHO

# %%
plt.figure(figsize=(16,5))
plt.title('PRHO Grid for Skewed RHO-P')
#grids.plot_mesh('Density','Pressure')
restart.plot_restarts('Density','Pressure')
plt.show()

# %% [markdown]
# ## RHOE

# %%
plt.figure(figsize=(16,5))
plt.title('RHOE Grid for Skewed RHO-P')
grids.plot_mesh('Density','StaticEnergy')
plt.show()

# %% [markdown]
# ## RHOT

# %%
plt.figure(figsize=(16,5))
plt.title('RHOT Grid for Skewed RHO-P')
grids.plot_mesh('Density','Temperature')
plt.show()

# %% [markdown]
# ## PS

# %%
plt.figure(figsize=(16,5))
plt.title('PS Grid for Skewed RHO-P')
grids.plot_mesh('Pressure','Entropy')
plt.show()

# %% [markdown]
# ## PT

# %%
plt.figure(figsize=(16,5))
plt.title('PT Grid for Skewed RHO-P')
grids.plot_mesh('Pressure','Temperature')
plt.show()

# %% [markdown]
# ## HS

# %%
plt.figure(figsize=(16,5))
plt.title('HS Grid for Skewed RHO-P')
grids.plot_mesh('Enthalpy','Entropy')
plt.show()
